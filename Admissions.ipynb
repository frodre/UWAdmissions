# %%
import tabula

# %%
pdf = 'data/admissions05-by-ethnicity.pdf'

# %%
tabula.read_pdf(pdf, pages='1')
# Out:
#                         Unnamed: 0    Unnamed: 1 African Amer.  Asian Amer.  \
# 0                              NaN           NaN   Male Female  Male Female
# 1   rchitecture and Urban Planning           NaN           NaN          NaN
# 2                     Architecture  Applications           1 3        14 27
# 3                              NaN        Offers           0 1          6 7
# 4                              NaN       %Offers          0 33        43 26
# 5                              NaN     Enrollees           0 1          4 2
# 6                              NaN    %Enrollees           100        67 29
# 7                Built Environment  Applications           0 0          0 0
# 8                              NaN        Offers           0 0          0 0
# 9                              NaN       %Offers           NaN          NaN
# 10                             NaN     Enrollees           0 0          0 0
# ...
